# %% [markdown]
# # Deep Deterministic Policy Gradients (DDPG)
# ---
# In this notebook, we train DDPG with Farama Foundation's Gymnasium BipedalWalker-v3 environment.
#
# ### 1. Import the Necessary Packages

# %%
import gymnasium as gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
env = gym.make('BipedalWalker-v3', render_mode="human")
# env.seed(10)
agent = Agent(state_size=env.observation_space.shape[0], action_size=env.action_space.shape[0], random_seed=10)

# %% [markdown]
# ### 3. Train the Agent with DDPG
#
# Run the code cell below to train the agent from scratch.  Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def ddpg(env, n_episodes=10000, max_t=700):
    scores_deque = deque(maxlen=100)
    scores = []
    max_score = -np.Inf

    for i_episode in range(1, n_episodes+1):
        state, info = env.reset(seed=42)
        agent.reset()
        score = 0

        for t in range(max_t):
            action = agent.act(state)
            next_state, reward, terminated, truncated, info = env.step(action)
            agent.step(state, action, reward, next_state, terminated or truncated)
            state = next_state
            score += reward

            if terminated or truncated:
                break

        scores_deque.append(score)
        scores.append(score)

        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), score), end="")

        if i_episode % 100 == 0:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))

        if np.mean(scores_deque)>=300.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_deque)))
            break

    return scores

env = gym.make('BipedalWalker-v3')
scores = ddpg(env)
env.close()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 100	Average Score: -90.41	Score: -37.097
# Episode 200	Average Score: -92.73	Score: -101.68
# Episode 300	Average Score: -105.38	Score: -107.40
# Episode 400	Average Score: -91.21	Score: -105.759
# Episode 500	Average Score: -68.27	Score: -45.369
# Episode 600	Average Score: -82.38	Score: -101.64
# Episode 700	Average Score: -105.01	Score: -115.64
# Episode 800	Average Score: -82.63	Score: -29.5020
# Episode 900	Average Score: -91.61	Score: -52.166
# Episode 1000	Average Score: -80.97	Score: -107.40
# Episode 1100	Average Score: -109.75	Score: -96.967
# Episode 1200	Average Score: -119.85	Score: -97.529
# Episode 1300	Average Score: -100.41	Score: -99.547
# Episode 1400	Average Score: -91.49	Score: -101.808
# Episode 1500	Average Score: -86.71	Score: -113.12
# Episode 1600	Average Score: -93.34	Score: -95.822
# Episode 1700	Average Score: -101.55	Score: -100.97
# Episode 1800	Average Score: -98.59	Score: -92.1898
# Episode 1900	Average Score: -93.08	Score: -101.97
# Episode 2000	Average Score: -112.88	Score: -114.33
# Episode 2100	Average Score: -110.62	Score: -114.73
# Episode 2200	Average Score: -110.23	Score: -105.57
# Episode 2300	Average Score: -105.40	Score: -98.453
# Episode 2400	Average Score: -95.51	Score: -140.534
# Episode 8000	Average Score: -126.56	Score: -142.58
# Episode 8100	Average Score: -129.61	Score: -139.24
# Episode 8200	Average Score: -125.92	Score: -136.22
# Episode 8300	Average Score: -80.82	Score: -36.4448
# Episode 8400	Average Score: -56.94	Score: -95.260
# Episode 8500	Average Score: -106.19	Score: -126.11
# Episode 8600	Average Score: -94.48	Score: -126.430
# Episode 8700	Average Score: -127.40	Score: -130.14
# Episode 8800	Average Score: -126.68	Score: -126.63
# Episode 8900	Average Score: -110.45	Score: -108.45
# Episode 9000	Average Score: -107.10	Score: -105.92
# Episode 9100	Average Score: -101.54	Score: -126.68
# Episode 9200	Average Score: -124.67	Score: -127.19
# Episode 9300	Average Score: -124.27	Score: -132.33
# Episode 9400	Average Score: -124.16	Score: -120.46
# Episode 9500	Average Score: -129.28	Score: -138.61
# Episode 9600	Average Score: -124.99	Score: -111.12
# Episode 9700	Average Score: -87.54	Score: -137.406
# Episode 9800	Average Score: -89.29	Score: -46.382
# Episode 9900	Average Score: -108.58	Score: -111.13
# Episode 10000	Average Score: -110.62	Score: -108.88

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
env = gym.make('BipedalWalker-v3', render_mode="human")

agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

state, info = env.reset(seed=42)
agent.reset()

while True:
    action = agent.act(state)
    env.render()
    next_state, reward, terminated, truncated, info = env.step(action)
    print('action: ', action)
    state = next_state

    if terminated or truncated:
        break

env.close()
# Out:
# action:  [-0.49888128 -0.8721513  -0.8304708   1.        ]
# action:  [-0.6588838  -0.7537215  -0.74158806  1.        ]
# action:  [-0.51992947 -0.6841464  -0.74840266  1.        ]
# action:  [-0.5450147  -0.56450945 -0.65697336  1.        ]
# action:  [-0.42548844 -0.5580561  -0.64905345  1.        ]
# action:  [-0.3651104  -0.50272566 -0.5919374   1.        ]
# action:  [-0.2708171  -0.40274096 -0.45585936  1.        ]
# action:  [-0.25734895 -0.38367835 -0.40364936  1.        ]
# action:  [-0.21250542 -0.34685162 -0.44771335  1.        ]
# action:  [-0.16918154 -0.3246351   1.          1.        ]
# action:  [-0.15583158 -0.33303753  1.          1.        ]
# action:  [-0.25043786 -0.38395023  0.36324656  1.        ]
# action:  [-0.3043432  -0.46990594  1.          1.        ]
# action:  [-0.2112782  -0.4994566   0.04141984  1.        ]
# action:  [-0.20065546 -0.4710369  -0.02266625  1.        ]
# action:  [-0.26654392 -0.44333914 -0.19206674  1.        ]
# action:  [-0.16459413 -0.39160922  0.99508476  1.        ]
# action:  [-0.06511392 -0.4680182  -0.15885915  1.        ]
# action:  [-0.1214483  -0.28607327 -0.12375169  1.        ]
# action:  [-0.36763278  1.         -0.25393263  1.        ]
# action:  [-0.3822384  -0.16308536 -0.34442586  1.        ]
# action:  [-0.41407403 -0.13483204 -0.35805908  1.        ]
# action:  [-0.37825403 -0.21512401 -0.38597655  1.        ]
# action:  [-0.47040394 -0.20285463 -0.34590062  1.        ]
# action:  [-0.46656033 -0.22394936 -0.42333332  1.        ]
# action:  [-0.39694127 -0.15281525 -0.45467865  1.        ]
# action:  [-0.410116   -0.11565138  1.          1.        ]
# action:  [-0.3149351  0.7070747  1.         1.       ]
# action:  [-0.36407664  0.6519077   1.          0.28330037]
# action:  [-0.32893726  1.         -0.08821142  0.00544907]
# action:  [-0.3869776   1.         -0.22782348 -0.08425963]
# action:  [-0.32901603  1.          1.         -0.04850238]
# action:  [-0.28688902  1.          1.          0.23917072]
# action:  [-0.37899497  1.          1.          0.37320253]
# action:  [-0.39554924  1.          1.          0.30511233]
# action:  [-0.31744277  1.          1.          0.41183445]
# action:  [-0.24482946  1.          1.          0.35334215]
# action:  [-0.13577062  1.          1.          0.31866327]
# action:  [-0.03047956  1.          1.          0.3132567 ]
# action:  [0.12964223 1.         1.         0.16653737]
# action:  [-0.44288406  1.          1.         -0.38331398]
# action:  [-0.5145196   1.          1.         -0.22629666]
# action:  [-0.459201    1.          1.          0.57299346]
# action:  [-0.4428827   1.          1.         -0.07851457]
# action:  [ 1.         1.         1.        -0.3349293]
# action:  [-0.17794394  1.          1.          0.05256259]
# action:  [0.15998445 1.         1.         1.        ]
# action:  [-0.16025238  1.          1.          0.8735713 ]
# action:  [ 0.45314166  1.          1.         -0.4543701 ]
# action:  [-0.13821007  1.          1.          0.9200154 ]
# action:  [0.5766569 1.        1.        1.       ]
# action:  [ 0.728658    1.          1.         -0.03338929]
# action:  [0.7231716  1.         1.         0.19443661]
# action:  [ 0.23426808  1.          1.         -0.21886832]
# action:  [-0.0847853   1.          1.         -0.16031586]
# action:  [-0.3005573   1.          1.         -0.18890254]

# %% [markdown]
# ### 5. Explore
#
# In this exercise, we have provided a sample DDPG agent and demonstrated how to use it to solve an OpenAI Gym environment.  To continue your learning, you are encouraged to complete any (or all!) of the following tasks:
# - Amend the various hyperparameters and network architecture to see if you can get your agent to solve the environment faster than this benchmark implementation.  Once you build intuition for the hyperparameters that work well with this environment, try solving a different OpenAI Gym task!
# - Write your own DDPG implementation.  Use this code as reference only when needed -- try as much as you can to write your own algorithm from scratch.
# - You may also like to implement prioritized experience replay, to see if it speeds learning.
# - The current implementation adds Ornsetein-Uhlenbeck noise to the action space.  However, it has [been shown](https://blog.openai.com/better-exploration-with-parameter-noise/) that adding noise to the parameters of the neural network policy can improve performance.  Make this change to the code, to verify it for yourself!
# - Write a blog post explaining the intuition behind the DDPG algorithm and demonstrating how to use it to solve an RL environment of your choosing.
