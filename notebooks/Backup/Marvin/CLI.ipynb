# %% [markdown]
# # Marvin CLI Example
#
# This example was copied and modified from https://www.askmarvin.ai/docs/interactive/cli/.

# %%
# !marvin say "hi"
# Out:
# ╭─ User ───────────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │  hi                                                                          │
# │                                                                              │
# ╭─ User ───────────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │  hi                                                                          │
# │                                                                              │
# ╭─ User ───────────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │  hi                                                                          │
# │                                                                              │
# ...
